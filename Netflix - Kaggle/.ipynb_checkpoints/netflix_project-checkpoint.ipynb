# %% [markdown]
# # Visualização de Dados
#
# Este projeto tem como objetivo desenvolver minha habilidade de visualização de dados. Para isso irei trabalhar o processo de análise exploratória de dados com o dataset de títulos disponíveis no catálogo da Netflix.
#
# Estes dados estão disponíveis no kaggle: https://www.kaggle.com/datasets/shivamb/netflix-shows

# %%
# Importando as bibliotecas que serão utilizadas neste trabalho

# Manipulação de Dados
import numpy as np
import pandas as pd
import datetime as dt
import missingno
from collections import defaultdict


# Visualização de Dados
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Analisando o inicio do dataset e as informações de cada coluna, é possível perceber que dentro dos dados estão contidos valores nulos e os dados não foram definidos no formato adequado no processo de importação.

# %%
# Verificando valores duplicados
df.duplicated().sum()
# Out:
# 0

# %%
# Analisando os valores nulos que estão contidos no dataset.
nulos = df.isnull().sum()

fig, ax = plt.subplots(figsize = (15, 7))
ax.bar(nulos.index,nulos.values, color = 'tab:red')
for i, v in enumerate(nulos):
    ax.annotate(text = v, xy = (i,v), ha = 'center', va = 'bottom'
                ,fontsize = 12, weight='ultralight')

ax.spines[['right','top']].set_visible(False)
    
plt.xticks(rotation = 45, fontsize = 12)
plt.title("Valores nulos no DataFrame\n", fontsize = 25, weight = 'bold')

plt.show()

# %% [markdown]
# Foi identificado que aproximadamente 25% das linhas possuem dados faltantes relacionados a direção da produção e 10% acerca de informações de atores e país de origem, iremos analisar as características destas produções. Em menor número poucos dados não possuem data de lançamento, nota e duração, para estes devido a baixa ocorrência poderam ser desconsiderados na análise

# %%
# Removendo as linhas com poucos valores nulos
df_limpo = df.dropna(axis = 0, subset = ['date_added','rating','duration'])

# %%
# Analisando as linhas com grande quantidade de valores nulos
df_null = df_limpo[df_limpo.isnull().any(axis = 1)].copy()
df_null.shape
# Out:
# (3458, 12)

# %% [markdown]
# Analisando se existem padrões nos dados faltantes

# %%
missingno.matrix(df_null)
# Out:
# <Axes: >

# %% [markdown]
# Não há coincidência aparente entre os dados faltantes nas colunas **director**, **cast** e **country**

# %%
# Verificando se existe alguma relação entre a falta de informações e o país de origem
# Gráfico contendo a distribuição de filmes por país no dataframe completo e no dataframe com valores nulos

# DataFrame Completo
df1 = df_limpo.value_counts('country')[:10]
# DataFrame Nulos
df2 = df_null.value_counts('country')[:10]

fig, (ax1, ax2) = plt.subplots(1,2, figsize = (20,9))

plt.subplot(121)
ax1.bar(df1.index,df1.values,color = 'tab:blue')
plt.xticks(rotation = 45, fontsize = 12)

for i, v in enumerate(df1):
    ax1.annotate(text = v, xy = (i,v), ha = 'center', va = 'bottom', fontsize = 15)

plt.title("Top 10 países DataFrame Completo\n", fontsize = 20, weight = 'bold')
    
plt.subplot(122)
ax2.bar(df2.index,df2.values, color = 'tab:red')
plt.xticks(rotation = 45, fontsize = 12)

for i, v in enumerate(df2):
    ax2.annotate(text = v, xy = (i,v), ha = 'center', va = 'bottom', fontsize = 15)

plt.title("Top 10 países DataFrame Nulos\n", fontsize = 25, weight = 'bold')

plt.show()

# %% [markdown]
# Através dos gráficos explicitados ainda não fica claro se existe alguma relação entre os valores nulos nos dados e o país de origem, porém alguns números se mostram interessantes, apenas 10% do total de filmes de origem indiana possuem valores nulos enquanto aproximadamente 50% dos filmes Britânicos faltam dados, a maioria dos cenários aparentam estar mais próximo do caso britânico do que indiano.
#
# * Existe alguma diferenciação no input de dados no país de origem ?
# * Regulação diferente por parte da Netflix ?
# * Maior rigor em Copyrights ?
#
# Estas questões atualmente não podem ser respondidas claramente através dos dados, mas seriam pontos a serem conferidos com o time de negócios responsável

# %%
# Convertendo os valores para o formato correto e limpando o dataset
df_limpo['date_added'] = pd.to_datetime(df_limpo['date_added'],format = 'mixed')
df_limpo.drop(columns = ['show_id','description'],inplace = True)

# %%
# Verificando a quantidade e proporção de linhas de Filmes e Séries

tvshow = df_limpo['type'].value_counts()
fig, ax = plt.subplots(figsize = (20,10))

def func(pct, allvals):
    absoluto = int(pct/100*np.sum(allvals))
    return "{:.1f}%\n({:d})".format(pct, absoluto)

ax.pie(tvshow, labels = tvshow.index
       ,colors = ['grey','tab:red']
       ,autopct = lambda pct: func(pct,tvshow.tolist())
       ,textprops=dict(fontsize=15
                       ,weight='ultralight'
                       ,style='italic')
       ,wedgeprops={'edgecolor':'white'})


plt.title("Quantidade de Filmes e Séries", fontsize = 25,weight='bold')
plt.show()

# %% [markdown]
# No gráfico acima é possível perceber que no catálogo da netflix temos uma presença maior de filmes, sendo ela mais que o dobro das séries.

# %%
# Quais são os atores mais frequentes no catálogo da Netflix ?

# Como para cada filme temos uma lista de atores, transformaremos esta série com lista contidas em uma lista única, para apartir de então contabilizar as repetições.
elenco = df_limpo['cast'].dropna()
elenco = [i for x in elenco for i in x.split(',')]
elenco = pd.DataFrame(elenco,columns = ['Atores']).value_counts().to_frame('Aparições').reset_index()

# %%
# Verificando os atores mais frequentes no catálogo 

elenco = elenco[:10]

fig, ax = plt.subplots(figsize=(10,5))

ax.bar(elenco['Atores'], elenco['Aparições'], color = 'tab:brown')
for i,v in enumerate(elenco['Aparições']):
    ax.annotate(v, xy = (i, v), ha = 'center', va = 'bottom', weight = 'bold')

plt.title('Top 10 Atores mais presentes no Catálogo', fontsize = 20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Dos 10 atores mais presentes no catálogo do Netflix, é possível perceber:
# * 5 Atores Indianos:
# Anupam Kher, Om Puri, Shah Rukh Khan, Rajesh Kava e Boman Irani
# * 4 Dubladores:
# Rupa Bhimani, Takahiro Sakurai, Julie Tejwani e Yuki Kaji e Andrea Libman
#
# Essa identificação pode sugerir outras pesquisas mais aprofundadas acerca de:
# * A mão de obra das principais produções Indianas são concentradas em um grupo seleto de atores?
# Talvez seja necessário um estudo mais aprofundado dos filmes Indianos fora da Netflix para responder esta questão
# * Existe uma grande grande quantidade de obras animadas no quadrado que demandam bastante de dubladores ou no mercado de dublagem também há uma concentração da mão de obra?
# Em geral os dubladores presentes nesse top 10 são atores de voz de animações/animes.
#
# Se segmentarmos a análise para filmes e séries os resultados seriam diferentes ?

# %%
# Vamos verificar o elenco mais frequente de maneira segmentada

# Elenco dos filmes:
df_filme = df_limpo.loc[df_limpo['type']=='Movie'].reset_index(drop=True)
elenco_f = df_filme['cast'].dropna()
elenco_f = [i for x in elenco_f for i in x.split(',')]
elenco_f = pd.DataFrame(elenco_f,columns = ['Atores']).value_counts().to_frame('Aparições').reset_index()

# Elenco das séries:
df_serie = df_limpo.loc[df_limpo['type']=='TV Show'].reset_index(drop=True)
elenco_s = df_serie['cast'].dropna()
elenco_s = [i for x in elenco_s for i in x.split(',')]
elenco_s = pd.DataFrame(elenco_s,columns = ['Atores']).value_counts().to_frame('Aparições').reset_index()

# %%
# Atores mais frequentes no catálogo

# Filmes
elenco_f = elenco_f[:10]

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(18,8))

ax1.bar(elenco_f['Atores'], elenco_f['Aparições'], color = 'brown')

for i, v in enumerate(elenco_f['Aparições']):
    ax1.annotate(text = v, xy = (i, v), ha = 'center', va = 'bottom', weight = 'bold',  fontsize = 12)

ax1.set_title('Top 10 atores mais presentes em Filmes', fontsize = 20)
ax1.set_xticklabels(ax1.xaxis.get_ticklabels(), rotation=45)


# Séries
elenco_s=elenco_s[:10]


ax2.bar(elenco_s['Atores'], elenco_s['Aparições'], color = 'tab:brown')

for i, v in enumerate(elenco_s['Aparições']):
    ax2.annotate(text = v, xy = (i, v), ha = 'center', va = 'bottom', weight = 'bold', fontsize = 12)


ax2.set_title('Top 10 atores mais presentes em Séries', fontsize = 20)
ax2.set_xticklabels(ax2.xaxis.get_ticklabels(), rotation=45)
plt.show()

# %% [markdown]
# Através dessa segmentação é possível perceber a frequência presente dos mesmos atores indianos nos filmes e nas nas séries de TV uma grande concentração de dubladores de animações.
#
# **Esses dados sugerem uma grande diversidade de atores estadunidenses, uma vez que estes possuem grande parte das obras presentes no catálogo mas não possuem nenhum ator dentre os mais frequentes nos filmes ou séries.**

# %%
# Segmentando a base para verificação dos diretores mais presentes
filmes = df_limpo.loc[df_limpo['type'] == 'Movie'].reset_index(drop = True)
series = df_limpo.loc[df_limpo['type'] == 'TV Show'].reset_index(drop = True)

# %%
# Diretores mais produções na plataforma:

dfilmes = filmes['director'].value_counts()[:10].sort_values()
dseries = series['director'].value_counts()[:10].sort_values()

fig, (ax1,ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (21,9))
sns.despine()

ax1.barh(dfilmes.index, dfilmes.values, color = 'brown')
for i, v in enumerate(dfilmes.values):
    ax1.annotate(text = v, xy = (v,i), ha = 'left', va = 'center', fontsize = 12, weight = 'bold')

ax1.set_title('Diretores com mais filmes', fontsize = 20, weight = 'bold')

ax2.barh(dseries.index,dseries.values, color = 'tab:brown')
for i, v in enumerate(dseries.values):
    ax2.annotate(text = v, xy = (v,i), ha = 'left', va = 'center', fontsize = 12, weight = 'bold')
    
ax2.set_title('Diretores com mais séries', fontsize = 20, weight = 'bold')


plt.show()
